# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/loan_data_set.csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
print(df['ApplicantIncome'].mean())
print(df['CoapplicantIncome'].mean())
# Out:
# 5403.459283387622
# 1621.245798027101

# %%
print(df['ApplicantIncome'].median())
print(df['CoapplicantIncome'].median())
# Out:
# 3812.5
# 1188.5

# %%
print(df['ApplicantIncome'].mode())
print(df['CoapplicantIncome'].mode())
# Out:
# 0    2500
# dtype: int64
# 0    0.0
# dtype: float64

# %%
print(df['ApplicantIncome'].min())
print(df['CoapplicantIncome'].min())
# Out:
# 150
# 0.0

# %%
print(df['ApplicantIncome'].max())
print(df['CoapplicantIncome'].max())
# Out:
# 81000
# 41667.0

# %%
print(df['ApplicantIncome'].std())
print(df['CoapplicantIncome'].std())
# Out:
# 6109.041673387174
# 2926.2483692241917

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
gk=df.groupby('Gender')

# %%
gk.get_group('Male')
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 607  LP002964   Male     Yes          2  Not Graduate            No
# 608  LP002974   Male     Yes          0      Graduate            No
# 610  LP002979   Male     Yes         3+      Graduate            No
# 611  LP002983   Male     Yes          1      Graduate            No
# 612  LP002984   Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
gk.get_group('Female')
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 17   LP001036  Female      No          0      Graduate            No
# 29   LP001087  Female      No          2      Graduate           NaN
# 37   LP001112  Female     Yes          0      Graduate            No
# 45   LP001137  Female      No          0      Graduate            No
# 48   LP001146  Female     Yes          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 587  LP002917  Female      No          0  Not Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 604  LP002959  Female     Yes          1      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.groupby(df['Gender']).ApplicantIncome.agg(['min','max','mean','median','std'])
# Out:
#         min    max         mean  median          std
# Gender
# Female  210  19484  4643.473214  3583.0  3585.381488
# Male    150  81000  5446.460123  3865.0  6185.789262

# %% [markdown]
# ## **For Iris.csv**

# %%
df1=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/iris.csv')

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
g1=df1.groupby('variety')

# %%
g1.get_group('Setosa')
# Out:
#     sepal_length  sepal_width  petal_length  petal_width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...

# %%
g1.get_group('Versicolor')
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     variety
# 50           7.0          3.2           4.7          1.4  Versicolor
# 51           6.4          3.2           4.5          1.5  Versicolor
# 52           6.9          3.1           4.9          1.5  Versicolor
# 53           5.5          2.3           4.0          1.3  Versicolor
# 54           6.5          2.8           4.6          1.5  Versicolor
# 55           5.7          2.8           4.5          1.3  Versicolor
# 56           6.3          3.3           4.7          1.6  Versicolor
# 57           4.9          2.4           3.3          1.0  Versicolor
# 58           6.6          2.9           4.6          1.3  Versicolor
# 59           5.2          2.7           3.9          1.4  Versicolor
# 60           5.0          2.0           3.5          1.0  Versicolor
# 61           5.9          3.0           4.2          1.5  Versicolor
# 62           6.0          2.2           4.0          1.0  Versicolor
# ...

# %%
g1.get_group('Virginica')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 100           6.3          3.3           6.0          2.5  Virginica
# 101           5.8          2.7           5.1          1.9  Virginica
# 102           7.1          3.0           5.9          2.1  Virginica
# 103           6.3          2.9           5.6          1.8  Virginica
# 104           6.5          3.0           5.8          2.2  Virginica
# 105           7.6          3.0           6.6          2.1  Virginica
# 106           4.9          2.5           4.5          1.7  Virginica
# 107           7.3          2.9           6.3          1.8  Virginica
# 108           6.7          2.5           5.8          1.8  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
# 110           6.5          3.2           5.1          2.0  Virginica
# 111           6.4          2.7           5.3          1.9  Virginica
# 112           6.8          3.0           5.5          2.1  Virginica
# ...

# %%
df1.groupby(df1['variety']).sepal_length.agg(['min','max','mean','median','std'])
# Out:
#             min  max   mean  median       std
# variety
# Setosa      4.3  5.8  5.006     5.0  0.352490
# Versicolor  4.9  7.0  5.936     5.9  0.516171
# Virginica   4.9  7.9  6.588     6.5  0.635880

# %%
df1.groupby(df1['variety']).sepal_width.agg(['min','max','mean','median','std'])
# Out:
#             min  max   mean  median       std
# variety
# Setosa      2.3  4.4  3.428     3.4  0.379064
# Versicolor  2.0  3.4  2.770     2.8  0.313798
# Virginica   2.2  3.8  2.974     3.0  0.322497

# %%
df1.groupby(df1['variety']).petal_length.agg(['min','max','mean','median','std'])
# Out:
#             min  max   mean  median       std
# variety
# Setosa      1.0  1.9  1.462    1.50  0.173664
# Versicolor  3.0  5.1  4.260    4.35  0.469911
# Virginica   4.5  6.9  5.552    5.55  0.551895

# %%
df1.groupby(df1['variety']).petal_width.agg(['min','max','mean','median','std'])
# Out:
#             min  max   mean  median       std
# variety
# Setosa      0.1  0.6  0.246     0.2  0.105386
# Versicolor  1.0  1.8  1.326     1.3  0.197753
# Virginica   1.4  2.5  2.026     2.0  0.274650
